# %%
import pandas as pd
import numpy as np

# %%
monday = pd.read_csv('Monday-WorkingHours.pcap_ISCX.csv')
tuesday = pd.read_csv('Tuesday-WorkingHours.pcap_ISCX.csv')
wednesday = pd.read_csv('Wednesday-workingHours.pcap_ISCX.csv')
thursday_morning = pd.read_csv('Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
thursday_afternoon = pd.read_csv('Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
friday_morning = pd.read_csv('Friday-WorkingHours-Morning.pcap_ISCX.csv')
friday = pd.read_csv('Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
monday = monday.dropna()
tuesday = tuesday.dropna()
wednesday = wednesday.dropna()
thursday_morning = thursday_morning.dropna()
thursday_afternoon = thursday_afternoon.dropna()
friday_morning = friday_morning.dropna()
friday = friday.dropna()

# %%
pd.set_option('display.max_columns', 200)

# %%
monday.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      529854.000000    5.298540e+05       529854.000000
# mean        10642.304095    1.039053e+07           10.391408
# std         21388.879098    2.875346e+07          892.466680
# min             0.000000   -1.000000e+00            1.000000
# 25%            53.000000    1.760000e+02            2.000000
# 50%            80.000000    3.130400e+04            2.000000
# 75%           443.000000    3.559410e+05            4.000000
# max         65535.000000    1.200000e+08       219759.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count            529854.000000                 5.298540e+05
# mean                 11.518416                 5.324839e+02
# std                1173.389641                 6.229016e+03
# min                   0.000000                 0.000000e+00
# 25%                   1.000000                 1.800000e+01
# 50%                   2.000000                 6.800000e+01
# 75%                   3.000000                 1.870000e+02
# max              291922.000000                 1.323378e+06
#
#         Total Length of Bwd Packets   Fwd Packet Length Max  \
# count                  5.298540e+05           529854.000000
# mean                   1.790057e+04              190.920246
# std                    2.675631e+06              448.855956
# min                    0.000000e+00                0.000000
# 25%                    0.000000e+00                6.000000
# 50%                    1.440000e+02               40.000000
# 75%                    3.920000e+02               83.000000
# max                    6.554530e+08            23360.000000
#
#         Fwd Packet Length Min   Fwd Packet Length Mean  \
# count           529854.000000            529854.000000
# mean                20.279728                50.750208
# std                 36.277300                91.968575
# min                  0.000000                 0.000000
# 25%                  0.000000                 6.000000
# 50%                  6.000000                38.000000
# 75%                 40.000000                53.000000
# max               2293.000000              4638.923469
#
#         Fwd Packet Length Std  Bwd Packet Length Max   Bwd Packet Length Min  \
# count           529854.000000          529854.000000           529854.000000
# mean                57.459208             406.122317               49.930411
# std                146.525569             785.072812               74.806813
# min                  0.000000               0.000000                0.000000
# 25%                  0.000000               0.000000                0.000000
# 50%                  0.000000              91.000000                6.000000
# 75%                 26.162951             212.000000               94.000000
# max               7125.596846           13140.000000             2146.000000
#
#         Bwd Packet Length Mean   Bwd Packet Length Std   Flow IAT Mean  \
# count            529854.000000           529854.000000    5.298540e+05
# mean                164.789239              131.325550    1.069517e+06
# std                 276.998551              275.861116    5.113535e+06
# min                   0.000000                0.000000   -1.000000e+00
# 25%                   0.000000                0.000000    6.800000e+01
# 50%                  81.000000                0.000000    1.078900e+04
# 75%                 164.000000               17.677670    8.701992e+04
# max                2976.321839             2728.559021    1.197482e+08
#
#         Flow IAT Std   Flow IAT Max   Flow IAT Min  Fwd IAT Total  \
# count   5.298540e+05   5.298540e+05   5.298540e+05   5.298540e+05
# mean    1.540632e+06   4.324431e+06   2.937269e+05   1.010019e+07
# std     6.057656e+06   1.402827e+07   3.883390e+06   2.858318e+07
# min     0.000000e+00  -1.000000e+00  -1.400000e+01   0.000000e+00
# 25%     0.000000e+00   1.500000e+02   3.000000e+00   1.000000e+00
# 50%     1.218209e+02   3.089900e+04   4.000000e+00   4.000000e+00
# 75%     5.405994e+04   2.049175e+05   8.200000e+01   2.615842e+05
# max     8.480026e+07   1.199997e+08   1.197482e+08   1.200000e+08
#
#         Fwd IAT Mean   Fwd IAT Std   Fwd IAT Max   Fwd IAT Min  Bwd IAT Total  \
# count   5.298540e+05  5.298540e+05  5.298540e+05  5.298540e+05   5.298540e+05
# mean    2.116120e+06  1.045743e+06  4.175065e+06  1.466265e+06   9.135832e+06
# std     1.024606e+07  3.911986e+06  1.397273e+07  1.002981e+07   2.768970e+07
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%     1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00   0.000000e+00
# 50%     4.000000e+00  0.000000e+00  4.000000e+00  3.000000e+00   3.000000e+00
# 75%     4.085050e+04  2.107169e+04  1.055480e+05  4.900000e+01   6.403300e+04
# max     1.199870e+08  8.460293e+07  1.199999e+08  1.199870e+08   1.199996e+08
#
#         Bwd IAT Mean   Bwd IAT Std   Bwd IAT Max   Bwd IAT Min  Fwd PSH Flags  \
# count   5.298540e+05  5.298540e+05  5.298540e+05  5.298540e+05  529854.000000
# mean    1.817542e+06  8.094927e+05  3.373039e+06  1.245587e+06       0.064146
# std     9.715469e+06  3.598543e+06  1.290285e+07  9.456988e+06       0.245013
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 50%     3.000000e+00  0.000000e+00  3.000000e+00  1.000000e+00       0.000000
# 75%     1.252688e+04  4.080804e+02  3.671700e+04  4.000000e+00       0.000000
# max     1.199741e+08  8.441801e+07  1.199741e+08  1.199741e+08       1.000000
#
#         Bwd PSH Flags   Fwd URG Flags   Bwd URG Flags   Fwd Header Length  \
# count        529854.0        529854.0        529854.0        5.298540e+05
# mean              0.0             0.0             0.0       -1.320511e+04
# std               0.0             0.0             0.0        3.609474e+06
# min               0.0             0.0             0.0       -1.929350e+09
# 25%               0.0             0.0             0.0        4.000000e+01
# 50%               0.0             0.0             0.0        6.400000e+01
# 75%               0.0             0.0             0.0        1.080000e+02
# max               0.0             0.0             0.0        4.644908e+06
#
#         Bwd Header Length  Fwd Packets/s   Bwd Packets/s   Min Packet Length  \
# count        5.298540e+05   5.298540e+05    5.298540e+05       529854.000000
# mean        -3.055928e+03   6.023743e+04    6.010587e+03           19.655171
# std          6.210289e+05   2.289866e+05    3.539902e+04           25.000373
# min         -1.677705e+08   0.000000e+00    0.000000e+00            0.000000
# 25%          2.000000e+01   9.728679e+00    2.502369e-01            0.000000
# 50%          4.000000e+01   6.320928e+01    2.832348e+01            6.000000
# 75%          8.000000e+01   1.098901e+04    4.807692e+03           40.000000
# max          5.838440e+06   3.000000e+06    2.000000e+06         1359.000000
#
#         Max Packet Length   Packet Length Mean   Packet Length Std  \
# count       529854.000000        529854.000000       529854.000000
# mean           447.362551           102.636809          135.218236
# std            840.472334           160.220369          235.846139
# min              0.000000             0.000000            0.000000
# 25%              6.000000             6.000000            2.190890
# 50%             94.000000            60.000000           28.481573
# 75%            250.000000            99.200000          112.005952
# max          23360.000000          2456.000000         4414.547151
#
#         Packet Length Variance  FIN Flag Count   SYN Flag Count  \
# count             5.298540e+05   529854.000000    529854.000000
# mean              7.390727e+04        0.022950         0.064146
# std               2.099335e+05        0.149743         0.245013
# min               0.000000e+00        0.000000         0.000000
# 25%               4.800000e+00        0.000000         0.000000
# 50%               8.112000e+02        0.000000         0.000000
# 75%               1.254533e+04        0.000000         0.000000
# max               1.948823e+07        1.000000         1.000000
#
#         RST Flag Count   PSH Flag Count   ACK Flag Count   URG Flag Count  \
# count    529854.000000    529854.000000    529854.000000    529854.000000
# mean          0.000136         0.248657         0.306416         0.119971
# std           0.011656         0.432235         0.461005         0.324928
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         1.000000         0.000000
# max           1.000000         1.000000         1.000000         1.000000
#
#         CWE Flag Count   ECE Flag Count   Down/Up Ratio   Average Packet Size  \
# count         529854.0    529854.000000   529854.000000         529854.000000
# mean               0.0         0.000138        0.638901            116.627816
# std                0.0         0.011737        0.552698            166.171751
# min                0.0         0.000000        0.000000              0.000000
# 25%                0.0         0.000000        0.000000              9.000000
# 50%                0.0         0.000000        1.000000             75.750000
# 75%                0.0         0.000000        1.000000            126.500000
# max                0.0         1.000000      108.000000           3684.000000
#
#         Avg Fwd Segment Size   Avg Bwd Segment Size   Fwd Header Length.1  \
# count          529854.000000          529854.000000          5.298540e+05
# mean               50.750208             164.789239         -1.320511e+04
# std                91.968575             276.998551          3.609474e+06
# min                 0.000000               0.000000         -1.929350e+09
# 25%                 6.000000               0.000000          4.000000e+01
# 50%                38.000000              81.000000          6.400000e+01
# 75%                53.000000             164.000000          1.080000e+02
# max              4638.923469            2976.321839          4.644908e+06
#
#        Fwd Avg Bytes/Bulk   Fwd Avg Packets/Bulk   Fwd Avg Bulk Rate  \
# count            529854.0               529854.0            529854.0
# mean                  0.0                    0.0                 0.0
# std                   0.0                    0.0                 0.0
# min                   0.0                    0.0                 0.0
# 25%                   0.0                    0.0                 0.0
# 50%                   0.0                    0.0                 0.0
# 75%                   0.0                    0.0                 0.0
# max                   0.0                    0.0                 0.0
#
#         Bwd Avg Bytes/Bulk   Bwd Avg Packets/Bulk  Bwd Avg Bulk Rate  \
# count             529854.0               529854.0           529854.0
# mean                   0.0                    0.0                0.0
# std                    0.0                    0.0                0.0
# min                    0.0                    0.0                0.0
# 25%                    0.0                    0.0                0.0
# 50%                    0.0                    0.0                0.0
# 75%                    0.0                    0.0                0.0
# max                    0.0                    0.0                0.0
#
#        Subflow Fwd Packets   Subflow Fwd Bytes   Subflow Bwd Packets  \
# count        529854.000000        5.298540e+05         529854.000000
# mean             10.391408        5.324839e+02             11.518416
# std             892.466680        6.229016e+03           1173.389641
# min               1.000000        0.000000e+00              0.000000
# 25%               2.000000        1.800000e+01              1.000000
# 50%               2.000000        6.800000e+01              2.000000
# 75%               4.000000        1.870000e+02              3.000000
# max          219759.000000        1.323378e+06         291922.000000
#
#         Subflow Bwd Bytes  Init_Win_bytes_forward   Init_Win_bytes_backward  \
# count        5.298540e+05           529854.000000             529854.000000
# mean         1.790057e+04             9079.067317               3055.516170
# std          2.675631e+06            18175.247431              10136.311943
# min          0.000000e+00               -1.000000                 -1.000000
# 25%          0.000000e+00               -1.000000                 -1.000000
# 50%          1.440000e+02              115.000000                 -1.000000
# 75%          3.920000e+02             8192.000000                252.000000
# max          6.554530e+08            65535.000000              65535.000000
#
#         act_data_pkt_fwd   min_seg_size_forward   Active Mean    Active Std  \
# count      529854.000000           5.298540e+05  5.298540e+05  5.298540e+05
# mean            7.413404          -3.615017e+03  6.844308e+04  4.322452e+04
# std           851.813787           5.526661e+05  5.872672e+05  3.971692e+05
# min             0.000000          -8.388531e+07  0.000000e+00  0.000000e+00
# 25%             0.000000           2.000000e+01  0.000000e+00  0.000000e+00
# 50%             1.000000           3.200000e+01  0.000000e+00  0.000000e+00
# 75%             3.000000           3.200000e+01  0.000000e+00  0.000000e+00
# max        213557.000000           1.260000e+02  1.016597e+08  6.434950e+07
#
#          Active Max    Active Min     Idle Mean      Idle Std      Idle Max  \
# count  5.298540e+05  5.298540e+05  5.298540e+05  5.298540e+05  5.298540e+05
# mean   1.454082e+05  4.380898e+04  3.464336e+06  2.024652e+05  3.621095e+06
# std    1.028667e+06  4.993977e+05  1.297129e+07  2.170279e+06  1.340724e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.016597e+08  1.016597e+08  1.199997e+08  7.514502e+07  1.199997e+08
#
#            Idle Min
# count  5.298540e+05
# mean   3.274462e+06
# std    1.273287e+07
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.199997e+08

# %%
monday.columns.values[64]
# Out:
# ' Subflow Bwd Packets'

# %%
monday[' Subflow Bwd Packets'].describe()
# Out:
# count    529854.000000
# mean         11.518416
# std        1173.389641
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max      291922.000000
# Name:  Subflow Bwd Packets, dtype: float64

# %%
monday[' Subflow Bwd Packets'].unique()
# Out:
# array([     0,      4,      6,      1,     13,     11,      7,     14,
#             2,     10,     20,     12,     34,      5,      8,     53,
#             3,    101,     30,      9,     33,     65,     16,    134,
#           512,     31,     45,     85,     25,     23,     36,     40,
#            19,     15,   1396,     91,     56,   1807,     46,     17,
#            35,    284,     18,     83,     28,     26,   1737,     29,
#            32,     66,     21,    177,     27,     48,     67,    958,
#           192,    137,    495,     24,    122,     22,     39,     79,
#            44,    335,    173,    245,    351,     84,    406,     52,
#          1828,     74,     37,    176,    118,    320,    200,     49,
#           476,    520,     70,   1851,     38,     81,    150,     89,
#            43,    102,     47,     58,    126,     68,    146,     97,
#           115,     90,     54,     59,    321,     72,    161,    138,
#           383,     50,    188,     51,     95,    280,     76,   4116,
#           910,    107,    452,    281,    407,    228,    304,    270,
#           153,    249,    309,    266,    257,    336,    262,    112,
#          1056,    160,    108,    217,    215,    297,     42,    338,
#           113,    240,    287,    460,   5483, 189636,     93,     64,
#           224,     92,    106,     69,    152,     77,     96,     82,
#            94,    348,    601,   1357,    180,    404,   1096,    329,
#            55,    814,     41,     57,    890,    774,   1177, 291922,
#          1400,    891,   1343,     86,    197,    687,    465,    167,
#        279279,   7671,    259,    302,    402,    268,    231,    651,
#           214,    117,    130,    191,    310,    103,     63,    141,
#           109,    182,    132,    163,    254,     71, 256740,   1030,
#           210,    634,    199,   3409,     60,    221,    692,    209,
#           110,    184,     61,    260,    461,    265,    464,     78,
#           114,    496,    208,    154,    917,    275,    686,    251,
#           327,    357,    201,     87,    127,    104,    129,   4170,
#            88,    124,    125,    729,  28429,    155,    136,     73,
#           286,    202,   1839,    451,     99,     62,   1268,    252,
#           164,    256,    247,    370,   1648,    111,    447,    162,
#           171,    763,    343,    121,    133,    128,   1141,    172,
#           145,    379,    119,   4437,    151,    671,     80,    189,
#           238,   2382,    227,    139,   1104,    100,     75,   5056,
#           198,    372,    298,    165,    424,    441,    387,    519,
#           411,    212,    123,    116, 291260,   1912,    369,    185,
#          1964, 289585,   1437,    300,    234,    289, 280292,   1821,
#           142,    443,    751,    170,    158,   1871,    222,     98,
#           283,    149,    535,   1370, 283900,    258,    455,    204,
#           618,    291,    444,    229,    135,    207, 244716,   1215,
#           148,    596,   1685,    166,    290,    567,    186,    307,
#          1618,    935,    551,   1689,   1633,    339,   1263,    131,
#           225,    521,    487,    316,   1021,   1270,   1464,    352,
#           292,    665,    193,    105,    194,    299,    140,   1481,
#           420,    181,    237,   1194,    957,    178,    244,    190,
#           156,    855, 224490,    226,    405,    518,    175,    685,
#           394,    303,    437,    276,    396,   1520,    285,   1485,
#           314,    317,    549,    643,    825,    456,    203,    169,
#           777,   1085,   1704,    458,   1191,    600,    421,   1721,
#           656,    641,    360,    277,   1250,    216,    206,   1764,
#           261,   1768,    220,    669,    187,    179,    433,    174,
#           355,    802,    619,   1447,    399,    582,    409,   1044,
#           157,    403,   1500,    159,   1455,    246,    294,    219,
#           947,    250,    780,    657,    385,    243,   1175,    525,
#           375,    391,   1285,   1092,    570,   1039,    368,    574,
#           510,    616,    253,    408,    442,    548,    318,    839,
#          1467,    143,    218,    660,    211,    356,    575,    323,
#           341,    205,    144,    183,   1112,    305,    340,    416,
#           195,   1449,    120,   1034,   1304,    499,    577,    393,
#           481,    514,    263,    293,    760,    534,   2122,    938,
#           513,    381,   1503,    328,    274,    553,   1386,    566,
#           271,    239,   1075,    331,    311,    536,    326,   1987,
#          2074,    470,    430,    515,    604,    279,    400,    377,
#           296,   1046,    332,    319,    412,    561,    371,    490,
#           295,    147,   1080,   1638,   1906,    342,    168,   1463,
#           269,   1066,    235,    390,    434,    366,   1490,    898,
#           640,    423,   1540,   1093,    632,    213,    422,    223,
#           564,    264,    398,    354,    362,    358,    557,   1001,
#           440,    306,    554,    312,    386,    635,    346,   1114,
#           936,    380,    475,    541,    543,    449,    419,   1316,
#          3962,    388,   1622,    489,    887,    832,    924,    960,
#           711,   1377,    196,    480,    301,    308,    537,    790,
#           714,   1621,    914,    467,    594,    563,    278,   1350,
#          1032,    824,    248,    232,    919,    334,    630,   1799,
#          1027,   1133,    313,    230,    808,    783,    367,    466,
#           719,   1276,    906,    949,    893,   1051,   1198,    345,
#          1158,    698,    925,   1612,   2233,    915,    482,    486,
#           585,    571,    868,    613,    775,    866,    859,   4686,
#          1991,   2090,    439,    472,    670,    485,    373,    532,
#           478,    330,    962,    363,   1858,   3533,    508,    822,
#           834,    628,    382,    658,    880,    506,    923,    715,
#           694,   1026,    432,   1058,    392,    886,    769,   1229,
#           833,    588,    815,    817,    509,    272,   1795,    415,
#           241,    930,    675,   2614,    696,   2154,    365,    500,
#           740,    690,   1384,    904,    907,   1061,    414,    233,
#           417,    401,    374,   1004,    344,    590,    359,    468,
#           749,   4132,    397,    724,    236,   1413,    473,    899,
#           872,    527,    649,    784,   1427,   1157,    267,    736,
#           589,    974,    758,    972,   1705,    858,    610,    950,
#           531,    785,   2094,    349,    273,    897,    642,   2476,
#           436,   2261,    862,    507,    579,    559,    523,    662,
#           756,    805,    517,   2377,    288,    752,    325,    764,
#          2063,    811,    410,    920,   1880,   2294,    556,   1125,
#           446,    836,    609,   1196,    282,   1144,    765,   7197,
#         10063,   6259,   4245,    869,   6951,   8541,    315,   1122,
#           621,    875,    448,    916,    707,   1098,    255,   1340,
#           843,   2972,    607,    555,    871,    882,    983,    516,
#           637,    545,   1387,  22827,    501,    918,   1642,    939,
#          2490,    491,   1258,    587,   1498,   2903,   1233,   3528,
#          1565,    705,    731,    576,    569,   1631,   1140,   1529,
#          1506,    633,   1130,   5633,   1610,    324,   1774,    364,
#          1674,    492,    706,    337,  43008,   1510,   2388,    846,
#          1645,   1861,   2800,    838,    631,    977,   3435,   9026,
#          2526,    568,   2363,   1291,    848,    942,   1360,   1429,
#          2442,   2609,    677, 147504])

# %%
convert_dict = {' Subflow Bwd Packets': int} 

monday = monday.astype(convert_dict)

# %%
monday[' Subflow Bwd Packets'].describe()
# Out:
# count    529854.000000
# mean         11.518416
# std        1173.389641
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max      291922.000000
# Name:  Subflow Bwd Packets, dtype: float64

# %%
tuesday.dtypes
# Out:
#  Destination Port                 int64
#  Flow Duration                    int64
#  Total Fwd Packets                int64
#  Total Backward Packets           int64
# Total Length of Fwd Packets       int64
#  Total Length of Bwd Packets      int64
#  Fwd Packet Length Max            int64
#  Fwd Packet Length Min            int64
#  Fwd Packet Length Mean         float64
#  Fwd Packet Length Std          float64
# Bwd Packet Length Max             int64
#  Bwd Packet Length Min            int64
#  Bwd Packet Length Mean         float64
#  Bwd Packet Length Std          float64
# Flow Bytes/s                     object
#  Flow Packets/s                  object
#  Flow IAT Mean                  float64
#  Flow IAT Std                   float64
#  Flow IAT Max                     int64
#  Flow IAT Min                     int64
# Fwd IAT Total                     int64
#  Fwd IAT Mean                   float64
#  Fwd IAT Std                    float64
#  Fwd IAT Max                      int64
#  Fwd IAT Min                      int64
# Bwd IAT Total                     int64
#  Bwd IAT Mean                   float64
#  Bwd IAT Std                    float64
#  Bwd IAT Max                      int64
#  Bwd IAT Min                      int64
#                                  ...
#  CWE Flag Count                   int64
#  ECE Flag Count                   int64
#  Down/Up Ratio                    int64
#  Average Packet Size            float64
#  Avg Fwd Segment Size           float64
#  Avg Bwd Segment Size           float64
#  Fwd Header Length.1              int64
# Fwd Avg Bytes/Bulk                int64
#  Fwd Avg Packets/Bulk             int64
#  Fwd Avg Bulk Rate                int64
#  Bwd Avg Bytes/Bulk               int64
#  Bwd Avg Packets/Bulk             int64
# Bwd Avg Bulk Rate                 int64
# Subflow Fwd Packets               int64
#  Subflow Fwd Bytes                int64
#  Subflow Bwd Packets              int64
#  Subflow Bwd Bytes                int64
# Init_Win_bytes_forward            int64
#  Init_Win_bytes_backward          int64
#  act_data_pkt_fwd                 int64
#  min_seg_size_forward             int64
# Active Mean                     float64
#  Active Std                     float64
#  Active Max                       int64
#  Active Min                       int64
# Idle Mean                       float64
#  Idle Std                       float64
#  Idle Max                         int64
#  Idle Min                         int64
#  Label                           object
# Length: 79, dtype: object

# %%
days = pd.concat([monday, tuesday, wednesday, thursday_morning, thursday_afternoon, friday_morning, friday])

# %%
column_names = list(days.columns.values)
processed_names = []
for name in column_names:
    processed_names.append(name.strip())

print(processed_names)
days.columns = processed_names
# Out:
# ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
list(days.columns.values)[64]
# Out:
# 'Subflow Bwd Packets'

# %%
days['Flow Bytes/s'].astype(float).describe()
# Out:
# count    1.423535e+06
# mean              inf
# std               NaN
# min     -2.610000e+08
# 25%      1.213470e+02
# 50%      5.149535e+03
# 75%      1.666667e+05
# max               inf
# Name: Flow Bytes/s, dtype: float64

# %%
days['Flow Packets/s'].astype(float).describe()
# Out:
# count    1.423535e+06
# mean              inf
# std               NaN
# min     -2.000000e+06
# 25%      3.013322e+00
# 50%      1.290198e+02
# 75%      2.985075e+04
# max               inf
# Name: Flow Packets/s, dtype: float64

# %%
days['Subflow Bwd Packets'].describe()
# Out:
# count    1.423535e+06
# mean     1.318387e+01
# std      1.203788e+03
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      4.000000e+00
# max      2.846020e+05
# Name: Subflow Bwd Packets, dtype: float64

# %%
print(len(days))
# Out:
# 1423535

# %%
convert_dict = {'Flow Packets/s': np.float64,
                'Flow Bytes/s': np.float64} 

days = days.astype(convert_dict)

# %%
days['Flow Packets/s'].describe()
# Out:
# count    1.423535e+06
# mean              inf
# std               NaN
# min     -2.000000e+06
# 25%      3.013322e+00
# 50%      1.290198e+02
# 75%      2.985075e+04
# max               inf
# Name: Flow Packets/s, dtype: float64

# %%
# Out:
# count    1.422665e+06
# mean     1.684295e+06
# std      2.877094e+07
# min     -2.610000e+08
# 25%      1.213379e+02
# 50%      5.136207e+03
# 75%      1.666667e+05
# max      2.070000e+09
# Name: Flow Bytes/s, dtype: float64

# %%
days = days.replace([np.inf], np.nan)

# %%
days = days.dropna()

# %%
days['Flow Bytes/s'].describe()
# Out:
# count    1.422665e+06
# mean     1.684295e+06
# std      2.877094e+07
# min     -2.610000e+08
# 25%      1.213379e+02
# 50%      5.136207e+03
# 75%      1.666667e+05
# max      2.070000e+09
# Name: Flow Bytes/s, dtype: float64

# %%
days['Flow Packets/s'].describe()
# Out:
# count    1.422665e+06
# mean     8.040484e+04
# std      2.721110e+05
# min     -2.000000e+06
# 25%      3.002107e+00
# 50%      1.289491e+02
# 75%      2.985075e+04
# max      4.000000e+06
# Name: Flow Packets/s, dtype: float64

# %%
days.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      1.422665e+06   1.422665e+06       1.422665e+06
# mean       6.721608e+03   1.660644e+07       1.147389e+01
# std        1.616684e+04   3.573221e+07       9.015205e+02
# min        0.000000e+00  -1.300000e+01       1.000000e+00
# 25%        5.300000e+01   7.600000e+01       1.000000e+00
# 50%        8.000000e+01   3.048300e+04       2.000000e+00
# 75%        1.044000e+03   4.514711e+06       5.000000e+00
# max        6.553300e+04   1.200000e+08       2.079640e+05
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            1.422665e+06                 1.422665e+06
# mean             1.319160e+01                 5.467803e+02
# std              1.204156e+03                 1.323332e+04
# min              0.000000e+00                 0.000000e+00
# 25%              1.000000e+00                 4.000000e+00
# 50%              2.000000e+00                 6.000000e+01
# 75%              4.000000e+00                 3.260000e+02
# max              2.846020e+05                 1.290000e+07
#
#        Total Length of Bwd Packets  Fwd Packet Length Max  \
# count                 1.422665e+06           1.422665e+06
# mean                  2.189628e+04           1.829633e+02
# std                   2.729068e+06           5.136366e+02
# min                   0.000000e+00           0.000000e+00
# 25%                   6.000000e+00           2.000000e+00
# 50%                   1.100000e+02           3.800000e+01
# 75%                   4.820000e+02           2.010000e+02
# max                   6.270000e+08           2.482000e+04
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           1.422665e+06            1.422665e+06           1.422665e+06
# mean            1.592906e+01            4.841178e+01           5.870649e+01
# std             4.114836e+01            1.237974e+02           1.731048e+02
# min             0.000000e+00            0.000000e+00           0.000000e+00
# 25%             0.000000e+00            2.000000e+00           0.000000e+00
# 50%             2.000000e+00            3.407143e+01           0.000000e+00
# 75%             3.500000e+01            5.100000e+01           7.248985e+01
# max             2.325000e+03            5.940857e+03           7.049469e+03
#
#        Bwd Packet Length Max  Bwd Packet Length Min  Bwd Packet Length Mean  \
# count           1.422665e+06           1.422665e+06            1.422665e+06
# mean            8.027733e+02           3.700773e+01            2.810687e+02
# std             1.746928e+03           6.416498e+01            5.500468e+02
# min             0.000000e+00           0.000000e+00            0.000000e+00
# 25%             6.000000e+00           0.000000e+00            6.000000e+00
# 50%             6.900000e+01           6.000000e+00            6.200000e+01
# 75%             2.870000e+02           6.500000e+01            1.770000e+02
# max             1.953000e+04           2.896000e+03            3.865000e+03
#
#        Bwd Packet Length Std  Flow Bytes/s  Flow Packets/s  Flow IAT Mean  \
# count           1.422665e+06  1.422665e+06    1.422665e+06   1.422665e+06
# mean            2.943900e+02  1.684295e+06    8.040484e+04   1.354101e+06
# std             7.069560e+02  2.877094e+07    2.721110e+05   4.273461e+06
# min             0.000000e+00 -2.610000e+08   -2.000000e+06  -1.300000e+01
# 25%             0.000000e+00  1.213379e+02    3.002107e+00   5.566667e+01
# 50%             0.000000e+00  5.136207e+03    1.289491e+02   1.020867e+04
# 75%             8.400000e+01  1.666667e+05    2.985075e+04   3.702625e+05
# max             6.694376e+03  2.070000e+09    4.000000e+06   1.200000e+08
#
#        Flow IAT Std  Flow IAT Max  Flow IAT Min  Fwd IAT Total  Fwd IAT Mean  \
# count  1.422665e+06  1.422665e+06  1.422665e+06   1.422665e+06  1.422665e+06
# mean   3.222575e+06  1.008924e+07  1.051692e+05   1.635769e+07  2.882024e+06
# std    8.589310e+06  2.593383e+07  2.234952e+06   3.565974e+07  1.002699e+07
# min    0.000000e+00 -1.300000e+01 -1.400000e+01   0.000000e+00  0.000000e+00
# 25%    0.000000e+00  7.000000e+01  3.000000e+00   0.000000e+00  0.000000e+00
# 50%    8.016026e+01  2.583700e+04  1.000000e+01   1.700000e+01  1.100000e+01
# 75%    9.498673e+05  3.584672e+06  7.300000e+01   2.854150e+06  4.821004e+05
# max    8.480000e+07  1.200000e+08  1.200000e+08   1.200000e+08  1.200000e+08
#
#         Fwd IAT Std   Fwd IAT Max   Fwd IAT Min  Bwd IAT Total  Bwd IAT Mean  \
# count  1.422665e+06  1.422665e+06  1.422665e+06   1.422665e+06  1.422665e+06
# mean   3.625359e+06  9.987038e+06  1.107393e+06   1.137641e+07  2.122942e+06
# std    1.029345e+07  2.594854e+07  9.021053e+06   3.081186e+07  9.776164e+06
# min    0.000000e+00  0.000000e+00 -8.000000e+00   0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# 50%    0.000000e+00  1.200000e+01  3.000000e+00   1.000000e+00  1.000000e+00
# 75%    1.134928e+05  1.956009e+06  4.900000e+01   9.926900e+04  1.610120e+04
# max    8.440000e+07  1.200000e+08  1.200000e+08   1.200000e+08  1.200000e+08
#
#         Bwd IAT Std   Bwd IAT Max   Bwd IAT Min  Fwd PSH Flags  Bwd PSH Flags  \
# count  1.422665e+06  1.422665e+06  1.422665e+06   1.422665e+06      1422665.0
# mean   1.670124e+06  5.284902e+06  1.165452e+06   4.721140e-02            0.0
# std    6.854826e+06  1.840040e+07  9.110529e+06   2.120908e-01            0.0
# min    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00            0.0
# 25%    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00            0.0
# 50%    0.000000e+00  1.000000e+00  1.000000e+00   0.000000e+00            0.0
# 75%    1.291924e+04  5.904000e+04  4.600000e+01   0.000000e+00            0.0
# max    8.340000e+07  1.200000e+08  1.200000e+08   1.000000e+00            0.0
#
#        Fwd URG Flags  Bwd URG Flags  Fwd Header Length  Bwd Header Length  \
# count   1.422665e+06      1422665.0       1.422665e+06       1.422665e+06
# mean    2.214154e-04            0.0      -3.406363e+04      -1.202809e+03
# std     1.487839e-02            0.0       2.851365e+07       1.273331e+06
# min     0.000000e+00            0.0      -3.221223e+10      -1.073741e+09
# 25%     0.000000e+00            0.0       4.000000e+01       2.000000e+01
# 50%     0.000000e+00            0.0       6.400000e+01       4.000000e+01
# 75%     0.000000e+00            0.0       1.360000e+02       1.120000e+02
# max     1.000000e+00            0.0       4.369484e+06       5.692040e+06
#
#        Fwd Packets/s  Bwd Packets/s  Min Packet Length  Max Packet Length  \
# count   1.422665e+06   1.422665e+06       1.422665e+06       1.422665e+06
# mean    7.213832e+04   8.367023e+03       1.513939e+01       8.476808e+02
# std     2.644431e+05   4.175656e+04       2.482385e+01       1.783606e+03
# min     0.000000e+00   0.000000e+00       0.000000e+00       0.000000e+00
# 25%     1.669064e+00   1.047418e-01       0.000000e+00       6.000000e+00
# 50%     6.580246e+01   1.861088e+01       2.000000e+00       7.600000e+01
# 75%     1.587302e+04   9.132420e+03       3.500000e+01       5.170000e+02
# max     3.000000e+06   2.000000e+06       1.359000e+03       2.482000e+04
#
#        Packet Length Mean  Packet Length Std  Packet Length Variance  \
# count        1.422665e+06       1.422665e+06            1.422665e+06
# mean         1.552852e+02       2.542135e+02            3.414839e+05
# std          2.746742e+02       5.261730e+02            1.094074e+06
# min          0.000000e+00       0.000000e+00            0.000000e+00
# 25%          3.333333e+00       2.309401e+00            5.333333e+00
# 50%          5.266667e+01       2.081346e+01            4.332000e+02
# 75%          1.144000e+02       1.607839e+02            2.585145e+04
# max          2.417842e+03       4.708990e+03            2.220000e+07
#
#        FIN Flag Count  SYN Flag Count  RST Flag Count  PSH Flag Count  \
# count    1.422665e+06    1.422665e+06    1.422665e+06    1.422665e+06
# mean     3.436086e-02    4.721140e-02    2.692131e-04    3.763507e-01
# std      1.821544e-01    2.120908e-01    1.640551e-02    4.844698e-01
# min      0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 50%      0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 75%      0.000000e+00    0.000000e+00    0.000000e+00    1.000000e+00
# max      1.000000e+00    1.000000e+00    1.000000e+00    1.000000e+00
#
#        ACK Flag Count  URG Flag Count  CWE Flag Count  ECE Flag Count  \
# count    1.422665e+06    1.422665e+06    1.422665e+06    1.422665e+06
# mean     2.755807e-01    6.325312e-02    2.214154e-04    2.692131e-04
# std      4.468066e-01    2.434178e-01    1.487839e-02    1.640551e-02
# min      0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 50%      0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 75%      1.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# max      1.000000e+00    1.000000e+00    1.000000e+00    1.000000e+00
#
#        Down/Up Ratio  Average Packet Size  Avg Fwd Segment Size  \
# count   1.422665e+06         1.422665e+06          1.422665e+06
# mean    6.500132e-01         1.724843e+02          4.841178e+01
# std     5.703064e-01         2.937936e+02          1.237974e+02
# min     0.000000e+00         0.000000e+00          0.000000e+00
# 25%     0.000000e+00         5.000000e+00          2.000000e+00
# 50%     1.000000e+00         6.850000e+01          3.407143e+01
# 75%     1.000000e+00         1.448036e+02          5.100000e+01
# max     1.560000e+02         3.558000e+03          5.940857e+03
#
#        Avg Bwd Segment Size  Fwd Header Length.1  Fwd Avg Bytes/Bulk  \
# count          1.422665e+06         1.422665e+06           1422665.0
# mean           2.810687e+02        -3.406363e+04                 0.0
# std            5.500468e+02         2.851365e+07                 0.0
# min            0.000000e+00        -3.221223e+10                 0.0
# 25%            6.000000e+00         4.000000e+01                 0.0
# 50%            6.200000e+01         6.400000e+01                 0.0
# 75%            1.770000e+02         1.360000e+02                 0.0
# max            3.865000e+03         4.369484e+06                 0.0
#
#        Fwd Avg Packets/Bulk  Fwd Avg Bulk Rate  Bwd Avg Bytes/Bulk  \
# count             1422665.0          1422665.0           1422665.0
# mean                    0.0                0.0                 0.0
# std                     0.0                0.0                 0.0
# min                     0.0                0.0                 0.0
# 25%                     0.0                0.0                 0.0
# 50%                     0.0                0.0                 0.0
# 75%                     0.0                0.0                 0.0
# max                     0.0                0.0                 0.0
#
#        Bwd Avg Packets/Bulk  Bwd Avg Bulk Rate  Subflow Fwd Packets  \
# count             1422665.0          1422665.0         1.422665e+06
# mean                    0.0                0.0         1.147389e+01
# std                     0.0                0.0         9.015205e+02
# min                     0.0                0.0         1.000000e+00
# 25%                     0.0                0.0         1.000000e+00
# 50%                     0.0                0.0         2.000000e+00
# 75%                     0.0                0.0         5.000000e+00
# max                     0.0                0.0         2.079640e+05
#
#        Subflow Fwd Bytes  Subflow Bwd Packets  Subflow Bwd Bytes  \
# count       1.422665e+06         1.422665e+06       1.422665e+06
# mean        5.467594e+02         1.319160e+01       2.189562e+04
# std         1.321300e+04         1.204156e+03       2.729003e+06
# min         0.000000e+00         0.000000e+00       0.000000e+00
# 25%         4.000000e+00         1.000000e+00       6.000000e+00
# 50%         6.000000e+01         2.000000e+00       1.100000e+02
# 75%         3.260000e+02         4.000000e+00       4.820000e+02
# max         1.287034e+07         2.846020e+05       6.270464e+08
#
#        Init_Win_bytes_forward  Init_Win_bytes_backward  act_data_pkt_fwd  \
# count            1.422665e+06             1.422665e+06      1.422665e+06
# mean             7.899813e+03             1.822687e+03      6.296838e+00
# std              1.459571e+04             8.160929e+03      7.306032e+02
# min             -1.000000e+00            -1.000000e+00      0.000000e+00
# 25%             -1.000000e+00            -1.000000e+00      0.000000e+00
# 50%              2.740000e+02             0.000000e+00      1.000000e+00
# 75%              8.192000e+03             2.350000e+02      2.000000e+00
# max              6.553500e+04             6.553500e+04      1.986360e+05
#
#        min_seg_size_forward   Active Mean    Active Std    Active Max  \
# count          1.422665e+06  1.422665e+06  1.422665e+06  1.422665e+06
# mean          -1.860242e+03  8.420146e+04  5.037345e+04  1.697506e+05
# std            1.006474e+06  7.030951e+05  4.351942e+05  1.110005e+06
# min           -5.368707e+08  0.000000e+00  0.000000e+00  0.000000e+00
# 25%            2.000000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 50%            2.400000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 75%            3.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# max            1.380000e+02  1.100000e+08  7.050000e+07  1.100000e+08
#
#          Active Min     Idle Mean      Idle Std      Idle Max      Idle Min
# count  1.422665e+06  1.422665e+06  1.422665e+06  1.422665e+06  1.422665e+06
# mean   5.561183e+04  9.380642e+06  2.642940e+05  9.606448e+06  9.148081e+06
# std    6.229521e+05  2.549257e+07  3.017683e+06  2.583671e+07  2.537716e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.100000e+08  1.200000e+08  7.660000e+07  1.200000e+08  1.200000e+08
